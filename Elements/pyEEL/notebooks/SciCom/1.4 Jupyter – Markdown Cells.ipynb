# %% [markdown]
# # Markdown in Jupyter

# %% [markdown]
# ### *Copyright 2021-2022 Dr. George Papagiannakis,  papagian@csd.uoc.gr*
# *All Rights Reserved*
# ### *University of Crete & Foundation for Research & Technology - Hellas (FORTH)*
#
# This notebook is also based on parts of [Lectures on scientific computing with Python](http://github.com/jrjohansson/scientific-python-lectures) by [J.R. Johansson](http://jrjohansson.github.io).
#
# ---

# %% [markdown]
# ## Markdown cells

# %% [markdown]
# Text can be added to Jupyter Notebooks using Markdown cells.  You can change the cell type to `Markdown` by using the "Cell Actions" menu, or with a hardware keyboard shortcut `m`.  Markdown is a popular markup language that is a superset of HTML. Its specification can be found here:
#
# <https://daringfireball.net/projects/markdown/>

# %% [markdown]
# As noted earlier, markdown cells can either be **rendered** or **unrendered**. When they are rendered, you will see a nice formatted representation of the cell's contents. When they are unrendered, you will see the raw text source of the cell. To render the selected cell, click the `▶︎` button. To unrender, select the  markdown cell, and then tap again on the rendered text.

# %% [markdown]
# ## Markdown basics

# %% [markdown]
# You can make text *italic* or **bold**.

# %% [markdown]
# You can build nested itemized or enumerated lists:
#
# * One
#     - Sublist
#         - This
#   - Sublist
#         - That
#         - The other thing
# * Two
#   - Sublist
# * Three
#   - Sublist

# %% [markdown]
# Now another list:
#
# 1. Here we go
#     1. Sublist
#     2. Sublist
# 2. There we go
# 3. Now this

# %% [markdown]
# You can add horizontal rules:
#
# ---

# %% [markdown]
# Here is a blockquote:
#
# > Beautiful is better than ugly.
# > Explicit is better than implicit.
# > Simple is better than complex.
# > Complex is better than complicated.
# > Flat is better than nested.
# > Sparse is better than dense.
# > Readability counts.
# > Special cases aren't special enough to break the rules.
# > Although practicality beats purity.
# > Errors should never pass silently.
# > Unless explicitly silenced.
# > In the face of ambiguity, refuse the temptation to guess.
# > There should be one-- and preferably only one --obvious way to do it.
# > Although that way may not be obvious at first unless you're Dutch.
# > Now is better than never.
# > Although never is often better than *right* now.
# > If the implementation is hard to explain, it's a bad idea.
# > If the implementation is easy to explain, it may be a good idea.
# > Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# And shorthand for links:
#
# [Jupyter's website](http://jupyter.org)

# %% [markdown]
# ## Headings

# %% [markdown]
# You can add headings by starting a line with one (or multiple) `#` followed by a space, as in the following example:
#
# ```
# # Heading 1
# # Heading 2
# ## Heading 2.1
# ## Heading 2.2
# ```

# %% [markdown]
# ## Embedded code

# %% [markdown]
# You can embed code meant for illustration instead of execution in Python:
#
#     def f(x):
#         """a docstring"""
#         return x**2
#
# or to import a module for geometric algebra with Clifford:
#
#     import clifford
#
#
# or other languages:
#
#     if (i=0; i<n; i++) {
#       printf("hello %d\n", i);
#       x += 4;
#     }
#
#
# or other markup languages:
#
#      this is an image

# %% [markdown]
# ## LaTeX equations

# %% [markdown]
# Courtesy of MathJax, you can include mathematical expressions both inline:
# $e^{i\pi} + 1 = 0$  and displayed:
#
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$
#
# Inline expressions can be added by surrounding the latex code with `$`:
#
# ```
# $e^{i\pi} + 1 = 0$
# ```
#
# Expressions on their own line are surrounded by `$$`:
#
# ```latex
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$
# ```

# %% [markdown]
# ## GitHub flavored markdown

# %% [markdown]
# The Notebook webapp supports Github flavored markdown meaning that you can use triple backticks for code blocks:
#
#     ```python
#     print "Hello World"
#     print ("hello world")
#     ```
#
#     ```javascript
#     console.log("Hello World")
#     ```
#
# Gives:
#
# ```python
# print "Hello World"
# ```
#
# ```javascript
# console.log("Hello World")
# ```

# %% [markdown]
# And a table like this:
#
#     | This | is   |
#     |------|------|
#     |   a  | table|
#
# A nice HTML Table:
#
# | This | is   |
# |------|------|
# |   a  | table|

# %% [markdown]
# ## General HTML

# %% [markdown]
# Because Markdown is a superset of HTML you can even add things like HTML tables:
#
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>

# %% [markdown]
# ## Local files

# %% [markdown]
# If you have local files in your Notebook directory, you can refer to these files in Markdown cells directly:
#
#     [subdirectory/]<filename>
#
# For example, in the images folder, we have the Python logo:
#
#     <img src="resources/python_logo.svg" />
#
# <img src="resources/python_logo.svg" />

# %% [markdown]
# ...And a video with the HTML5 video tag:
#
#     <video controls src="resources/animation.m4v" />
#
# <video controls src="resources/animation.m4v" />
#
# These do not embed the data into the notebook file, and require that the files exist when you are viewing the notebook.

# %% [markdown]
# ### Security of local files

# %% [markdown]
# Note that this means that the Jupyter notebook server also acts as a generic file server
# for files inside the same tree as your notebooks.  Access is not granted outside the
# notebook folder so you have strict control over what files are visible, but for this
# reason it is highly recommended that you do not run the notebook server with a notebook
# directory at a high level in your filesystem (e.g. your home directory).
#
# When you run the notebook in a password-protected manner, local file access is restricted
# to authenticated users unless read-only views are active.

# %% [markdown]
# ## Further examples of markdown

# %% [markdown]
#  this is how to use an image:
#  ![Image title](https://boostnote.io/assets/img/logo.png)
#   ![Image title](./_images/image1.png)
#
#  this is how to use a quotation:
#  > this is a quote!
#
# this is a link:
#   [Boostnote](https://boostnote.io)
#
#
# this is a check box:
# - [x] Task 1
# - [ ] Task 2
#
# this is a fold:
# <details><summary>Boostnote is a notepad corresponding to
# markdown notation, which is a tool for organizing and
# sharing information.</summary>
# - Features - <br>
# · Search function to find memos in one shot
# · Supports markdown notation <br>
# · Support for Mac, Windows, Linux, iOS, Android <br>
# · Export and import to Plain text (.txt), Markdown (.md)
# format <br>
# · Supports PDF saving <br>
# · Can be used offline <br>
# · Synchronize to dropbox etc. with setting <br>
# · Supports theme colors and numerous fonts <br>
# </details>
#
# this is for emphasis:
# *Italic type*
# **Bold**
# ~~Negative~~

# %% [markdown]
# ## Magic commands

# %%
# this is a magic call
# %pwd
# and these are another
# %ls -la
# %matplotlib inline
# Out:
# total 10040
# drwxr-xr-x  34 Giwrgakis  staff     1088 Aug 27 19:12 ./
# drwxr-xr-x   8 Giwrgakis  staff      256 Aug 27 18:51 ../
# -rw-r--r--   1 Giwrgakis  staff    23688 Aug 27 19:12 1.0 Git - Introduction.ipynb
# -rw-r--r--   1 Giwrgakis  staff    11252 Aug 27 19:14 1.1 Jupyter – Introduction.ipynb
# -rw-r--r--   1 Giwrgakis  staff    12485 Aug 27 19:14 1.2 Jupyter – Jupyter Editor.ipynb
# -rw-r--r--   1 Giwrgakis  staff    15625 Aug 27 19:14 1.3 Jupyter – Running Code.ipynb
# -rw-r--r--   1 Giwrgakis  staff    18418 Aug 28 23:18 1.4 Jupyter – Markdown Cells.ipynb
# -rw-r--r--   1 Giwrgakis  staff     8215 Aug 27 19:15 2.1 Python – Introduction.ipynb
# -rw-r--r--   1 Giwrgakis  staff    19634 Aug 27 19:15 2.2 Python – Variables and Fundamental Types.ipynb
# -rw-r--r--   1 Giwrgakis  staff    31996 Aug 27 19:15 2.3 Python – Compound Types.ipynb
# -rw-r--r--   1 Giwrgakis  staff    13448 Aug 27 19:15 2.4 Python – Control Flow and Loops.ipynb
# -rw-r--r--   1 Giwrgakis  staff    18559 Aug 27 19:15 2.5 Python – Functions and Classes.ipynb
# -rw-r--r--   1 Giwrgakis  staff    15000 Aug 27 19:15 2.6 Python – Modules and Exceptions.ipynb
# -rw-r--r--   1 Giwrgakis  staff     7710 Aug 27 19:16 3.1 NumPy – Multidimensional Data Arrays.ipynb
# -rw-r--r--   1 Giwrgakis  staff    32021 Aug 27 19:16 3.2 NumPy – Creating Arrays.ipynb
# -rw-r--r--   1 Giwrgakis  staff    18338 Aug 27 19:16 3.3 NumPy – File IO.ipynb
# -rw-r--r--   1 Giwrgakis  staff    22211 Aug 27 19:16 3.4 NumPy – Manipulating Arrays.ipynb
# -rw-r--r--   1 Giwrgakis  staff    46033 Aug 27 19:16 3.5 NumPy – Linear Algebra.ipynb
# -rw-r--r--   1 Giwrgakis  staff    15826 Aug 27 19:16 3.6 NumPy – Stacking and Iterating.ipynb
# -rw-r--r--   1 Giwrgakis  staff    15327 Aug 27 19:17 3.7 NumPy – Vectorization.ipynb
# -rw-r--r--   1 Giwrgakis  staff    16136 Aug 27 19:17 4.1 Matplotlib – Plotting in Python.ipynb
# -rw-r--r--   1 Giwrgakis  staff   103617 Aug 27 19:17 4.2 Matplotlib – Plotting and Saving Figures.ipynb
# -rw-r--r--   1 Giwrgakis  staff   337631 Aug 27 19:17 4.3 Matplotlib – Legends and Labels.ipynb
# -rw-r--r--   1 Giwrgakis  staff   433465 Aug 27 19:17 4.4 Matplotlib – Axes in Plots.ipynb
# -rw-r--r--   1 Giwrgakis  staff  2779620 Aug 27 19:17 4.5 Matplotlib – Other 2D Plots.ipynb
# -rw-r--r--   1 Giwrgakis  staff   734604 Aug 27 19:17 4.6 Matplotlib – 3D Figures.ipynb
# -rw-r--r--   1 Giwrgakis  staff    17070 Aug 27 19:18 5.1 Pandas – Data Structures.ipynb
# -rw-r--r--   1 Giwrgakis  staff    35633 Aug 27 19:19 5.2 Pandas – Reading Data.ipynb
# -rw-r--r--   1 Giwrgakis  staff    35503 Aug 27 19:19 5.3 Pandas – Inspecting DataFrames.ipynb
# -rw-r--r--   1 Giwrgakis  staff    43447 Aug 27 19:19 5.4 Pandas – Manipulating DataFrames.ipynb
# -rw-r--r--   1 Giwrgakis  staff   208636 Aug 27 19:22 5.5 Pandas – MovieLens Dataset.ipynb
# -rw-r--r--   1 Giwrgakis  staff        0 Aug 27 18:52 __init__.py
# drwxr-xr-x   8 Giwrgakis  staff      256 Aug 27 19:11 data/
# drwxr-xr-x   7 Giwrgakis  staff      224 Aug 27 19:11 resources/

# %% [markdown]
# ## Python system paths and versions

# %%
import sys
for p in sys.path:
	print(p)
# Out:
# /Users/Giwrgakis/MyProjects/Elements/pyEEL/pyEEL/examples/SciCom
# /Users/Giwrgakis/opt/anaconda3/envs/elements1.0/lib/python39.zip
# /Users/Giwrgakis/opt/anaconda3/envs/elements1.0/lib/python3.9
# /Users/Giwrgakis/opt/anaconda3/envs/elements1.0/lib/python3.9/lib-dynload
#
# /Users/Giwrgakis/opt/anaconda3/envs/elements1.0/lib/python3.9/site-packages
# /Users/Giwrgakis/MyProjects/experimental
# /Users/Giwrgakis/MyProjects/Elements/pyECSS
# /Users/Giwrgakis/MyProjects/Elements/pyEEL
# /Users/Giwrgakis/MyProjects/Elements/pyGLV
# /Users/Giwrgakis/opt/anaconda3/envs/elements1.0/lib/python3.9/site-packages/IPython/extensions
# /Users/Giwrgakis/.ipython

# %%
# %load_ext version_information

# %version_information
# Out:
# Software versions
# Python 3.9.7 64bit [Clang 10.0.0 ]
# IPython 7.29.0
# OS macOS 10.16 x86_64 i386 64bit
# Sun Aug 28 23:18:06 2022 EEST
