# %% [markdown]
# # WGPU notebook examples

# %% [markdown]
# ## Triangle example
#
# We import the triangle example and show it in the notebook.

# %%
from wgpu.gui.auto import WgpuCanvas, run
import _data.wgpu_triangle as triangle 

canvas = WgpuCanvas(size=(640, 480), title="wgpu triangle with jupyter")

triangle.main(canvas)
canvas
# Out:
# RFBOutputContext()
# JupyterWgpuCanvas(css_height='480px', css_width='640px')

# %% [markdown]
# ## Cube example
#
# An interactive example this time.

# %%
import _data.wgpu_cube as cube

canvas = WgpuCanvas(size=(640, 480), title="wgpu rotating cube jupyter")  

cube.main(canvas=canvas)
canvas
# Out:
# RFBOutputContext()
# JupyterWgpuCanvas(css_height='480px', css_width='640px')

# %% [markdown]
# ## Event example
#
# The code below is a copy from `show_events.py`. It is just to show how events are handled. These events are the same accross all auto-backends.

# %%
from wgpu.gui.auto import WgpuCanvas, run

class MyCanvas(WgpuCanvas):
    def handle_event(self, event):
        if event["event_type"] != "pointer_move":
            print(event)

canvas = MyCanvas(size=(640, 480), title="wgpu triangle with GLFW")
canvas
# Out:
# RFBOutputContext()
# {'event_type': 'resize', 'width': 640.0, 'height': 480.0, 'pixel_ratio': 1}
# MyCanvas(css_height='480px', css_width='640px')
# {'event_type': 'resize', 'width': 640, 'height': 480, 'pixel_ratio': 1}
# {'event_type': 'pointer_down', 'x': 197.96875, 'y': 131, 'button': 1, 'buttons': [1], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 197.96875, 'y': 131, 'pressure': 0.5}}}
# {'event_type': 'pointer_up', 'x': 197.96875, 'y': 131, 'button': 1, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 197.96875, 'y': 131, 'pressure': 0.5}}}
# {'event_type': 'pointer_down', 'x': 197.96875, 'y': 131, 'button': 1, 'buttons': [1], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 197.96875, 'y': 131, 'pressure': 0.5}}}
# {'event_type': 'double_click', 'x': 197, 'y': 129, 'button': 1, 'buttons': [], 'modifiers': []}
# {'event_type': 'pointer_up', 'x': 197.98046875, 'y': 129, 'button': 1, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 197.96875, 'y': 131, 'pressure': 0.5}}}
# {'event_type': 'pointer_down', 'x': 199.96875, 'y': 129, 'button': 2, 'buttons': [2], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 129, 'pressure': 0.5}}}
# {'event_type': 'pointer_up', 'x': 199.98046875, 'y': 127, 'button': 2, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 129, 'pressure': 0.5}}}
# {'event_type': 'pointer_down', 'x': 199.96875, 'y': 127, 'button': 2, 'buttons': [2], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_up', 'x': 199.96875, 'y': 127, 'button': 2, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_down', 'x': 199.96875, 'y': 127, 'button': 1, 'buttons': [1], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'double_click', 'x': 199, 'y': 127, 'button': 1, 'buttons': [], 'modifiers': []}
# {'event_type': 'pointer_up', 'x': 199.96875, 'y': 127, 'button': 1, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_down', 'x': 199.96875, 'y': 127, 'button': 2, 'buttons': [2], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_up', 'x': 199.96875, 'y': 127, 'button': 2, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_down', 'x': 199.96875, 'y': 127, 'button': 2, 'buttons': [2], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_up', 'x': 199.96875, 'y': 127, 'button': 2, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_down', 'x': 199.96875, 'y': 127, 'button': 1, 'buttons': [1], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_up', 'x': 199.96875, 'y': 127, 'button': 1, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_down', 'x': 199.96875, 'y': 127, 'button': 2, 'buttons': [2], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_up', 'x': 199.96875, 'y': 127, 'button': 2, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_down', 'x': 199.96875, 'y': 127, 'button': 1, 'buttons': [1], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_up', 'x': 199.96875, 'y': 127, 'button': 1, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_down', 'x': 199.96875, 'y': 127, 'button': 2, 'buttons': [2], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_up', 'x': 199.96875, 'y': 127, 'button': 1, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_down', 'x': 199.96875, 'y': 127, 'button': 2, 'buttons': [2], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'pointer_up', 'x': 199.96875, 'y': 127, 'button': 1, 'buttons': [], 'modifiers': [], 'ntouches': 1, 'touches': {'1': {'x': 199.96875, 'y': 127, 'pressure': 0.5}}}
# {'event_type': 'resize', 'width': 640, 'height': 480, 'pixel_ratio': 2}
# {'event_type': 'resize', 'width': 640, 'height': 480, 'pixel_ratio': 1}
# {'event_type': 'resize', 'width': 640, 'height': 480, 'pixel_ratio': 2}
# {'event_type': 'resize', 'width': 640, 'height': 480, 'pixel_ratio': 1}
# {'event_type': 'resize', 'width': 640, 'height': 480, 'pixel_ratio': 2}
# {'event_type': 'resize', 'width': 640, 'height': 480, 'pixel_ratio': 1}
